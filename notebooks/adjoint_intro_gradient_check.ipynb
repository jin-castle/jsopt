# %% [markdown]
# # Adjoint Introduction Style Gradient Check
#
# This notebook follows the validation pattern from NanoComp Meep's `python/examples/adjoint_optimization/01-Introduction.ipynb`: evaluate an objective gradient, sample finite-difference gradients, fit a line, and plot `finite difference gradient` versus `gradient`.
#
# The example uses a lightweight JAX bend-transmission surrogate so the gradient check runs quickly without requiring Meep.

# %% [markdown]
# ## Recorded result
#
# ```text
# seed: 240
# design_shape: (11, 11)
# objective: 0.25838318498002893
# gradient_shape: (121,)
# gradient_norm: 0.1386138675318683
# fd_step: 1e-05
# fd_samples: 20
# fit_slope_ad_over_fd: 0.9999999999883632
# fit_intercept: -2.483529989351481e-13
# correlation: 0.9999999999999999
# max_abs_error: 6.8232371792584234e-12
# max_relative_error: 5.706610818037915e-08
# mean_relative_error: 4.9529473969646876e-09
# gradient_check_ok: True
# ```

# %% [markdown]
# ## Design and gradient output
#
# ![Design and target](../results/gradient_check/adjoint_intro_style/01_design_and_target.png)
#
# ![Gradient heatmap](../results/gradient_check/adjoint_intro_style/02_adjoint_gradient_heatmap.png)

# %% [markdown]
# ## Finite difference comparison
#
# ![Finite difference comparison](../results/gradient_check/adjoint_intro_style/03_finite_difference_comparison.png)

# %%
# Reproduce from the repository root.
import os

os.environ["JSOPT_OUTPUT_DIR"] = "results/gradient_check/adjoint_intro_style"
# %run examples/adjoint_intro_gradient_check.py

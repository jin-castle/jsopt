# %% [markdown]
# # FDTDX CPU Result Notebook
#
# This notebook records the local CPU execution results committed under `results/cpu`. The PNGs were generated with `JSOPT_BACKEND=cpu` from the repository scripts.
#
# The committed FDTDX smoke scenes use a tiny quasi-2D/2.5D slab so the examples stay lightweight while matching the intended planar photonics workflow: x/y PML boundaries, periodic z, and a single-z-layer design parameter.

# %% [markdown]
# ## CPU gradient smoke result
#
# ```text
# devices: [CpuDevice(id=0)]
# default_backend: cpu
# requested_backend: cpu
# steps: 8 backend: cpu
# device_param_shape: (4, 4, 1)
# runtime_s: 24.84052276611328
# objective: 6.0384240896382835e-06
# gradient_shape: (4, 4, 1)
# gradient_finite: True
# gradient_norm: 2.4017538180487463e-06
# gradient_nonzero: True
# ```

# %% [markdown]
# ![CPU device parameter slices](../results/cpu/fdtdx_gradient_smoke/01_device_parameter_slices.png)
#
# ![CPU objective gradient slices](../results/cpu/fdtdx_gradient_smoke/02_objective_gradient_slices.png)
#
# ![CPU field energy slices](../results/cpu/fdtdx_gradient_smoke/03_final_field_energy_slices.png)
#
# ![CPU poynting flux detector map](../results/cpu/fdtdx_gradient_smoke/04_poynting_flux_detector_map.png)

# %% [markdown]
# ## CPU optimizer visual result
#
# ```text
# devices: [CpuDevice(id=0)]
# default_backend: cpu
# steps: 8 backend: cpu
# param_shape: (4, 4, 1)
# max_iters: 2 learning_rate: 0.02
# gradient_scale: 1.0
# runtime_s: 36.40138053894043
# initial_objective: 6.0384240896382835e-06
# final_evaluated_objective: 6.12574876868166e-06
# best_objective: 6.12574876868166e-06
# objective_improvement_from_initial: 8.732467904337682e-08
# best_gradient_norm: 2.412875089123028e-06
# final_design_delta_norm: 0.07043667312496735
# optimization_ok: True
# ```

# %% [markdown]
# ![CPU FDTDX setup plot](../results/cpu/fdtdx_optimizer_visual/00_fdtdx_plot_setup.png)
#
# ![CPU FDTDX material slices](../results/cpu/fdtdx_optimizer_visual/00_fdtdx_material_slices.png)
#
# ![CPU initial design slices](../results/cpu/fdtdx_optimizer_visual/01_initial_design_slices.png)
#
# ![CPU final design slices](../results/cpu/fdtdx_optimizer_visual/02_final_design_slices.png)
#
# ![CPU final design delta](../results/cpu/fdtdx_optimizer_visual/03_final_design_delta_slices.png)
#
# ![CPU objective history](../results/cpu/fdtdx_optimizer_visual/05_objective_history.png)
#
# ![CPU gradient norm history](../results/cpu/fdtdx_optimizer_visual/06_gradient_norm_history.png)
#
# ![CPU best field energy](../results/cpu/fdtdx_optimizer_visual/07_best_field_energy_slices.png)
#
# ![CPU best poynting flux map](../results/cpu/fdtdx_optimizer_visual/08_best_poynting_flux_detector_map.png)

# %%
# Reproduce the CPU PNG outputs from the repository root.
import os

os.environ["JSOPT_BACKEND"] = "cpu"
os.environ["JSOPT_OUTPUT_DIR"] = "results/cpu/fdtdx_gradient_smoke"
# %run notebooks/fdtdx_colab_gradient_smoke.py

os.environ["JSOPT_MAX_ITERS"] = "2"
os.environ["JSOPT_OUTPUT_DIR"] = "results/cpu/fdtdx_optimizer_visual"
# %run notebooks/fdtdx_colab_optimizer_visual.py
